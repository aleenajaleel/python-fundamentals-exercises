# %% [markdown]
# <a href="https://colab.research.google.com/github/aleenajaleel/python-fundamentals-exercises/blob/main/practice3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.positive ,negative or zero

# %%
number=int(input("enter the number"))
if number>0:
    print("positive")
elif number<0:
    print("negative")
else:
    print("zero")
# Out:
# enter the number 4
# positive

# %%
#2.even or odd

# %%
number=int(input("enter your number"))
if number%2==0:
  print("even number",number)
else:
  print("odd number",number)
# Out:
# enter your number6
# even number 6

# %%
#3.voting  eligibility

# %%
age=int(input("enter your age"))
if age>=18:
  print("your eligible for voting")
else:
  print("not eligible for voting")
# Out:
# enter your age56
# your eligible for voting

# %%
#4.greater number

# %%
num1=int(input("enter your first number"))
num2=int(input("enter your second number"))
if num1>num2:
  print("num1 is greater",num1)
else:
  print("num2 is greater",num2)
# Out:
# enter your first number2
# enter your second number5
# num2 is greater 5

# %%
#5.largest of three

# %%
num1=int(input("enter your first number"))
num2=int(input("enter your second number"))
num3=int(input("enter your third number"))
if num1>num2>num3:
  print("num1 is greater",num1)
elif num2>num1>num3:
  print("num2 is greater",num2)
else:
  print("num3 is greater",num3)
# Out:
# enter your first number7
# enter your second number4
# enter your third number0
# num1 is greater 7

# %%
#6.pass or fail

# %%
marks=int(input("enter your marks"))
if marks>=40:
  print("pass")
else:
  print("fail")
# Out:
# enter your marks34
# fail

# %%
#7.divisable by 5

# %%
number=int(input("enter your number"))
if number%5==0:
  print("divisable by 5")
else:
  print("not divisable")
# Out:
# enter your number54
# not divisable

# %%
#8.temperature check

# %%
temperature=int(input("enter temperature"))
if temperature<20:
  print("cold")
elif temperature >=20 :
  print("normal")
elif temperature<=30:
  print("normal")
else:
  print("hot")
# Out:
# enter temperature23
# normal

# %%
#9.number category

# %%
number=int(input("enter your number"))
if number<9:
  print("one digit")
elif number<99:
  print("two digit")
elif number<999:
  print("three digit")
# Out:
# enter your number453
# three digit

# %%
#10.simple calculator

# %%
num1=int(input("enter your number"))
num2=int(input("enter your number"))
operator=input("enter your operator")
if operator=="+":
  print(num1+num2)
elif operator=="-":
  print(num1-num2)
elif operator=="*":
  print(num1*num2)
elif operator=="/":
  print(num1/num2)
else:
  print("invalid operator")
# Out:
# enter your number34
# enter your number1
# enter your operator+
# 35

# %%
#11.student grade

# %%
mark=int(input("enter your mark"))
if mark>=90:
  print("grade:A+")
elif  mark>=80 and mark<=89:
  print("grade:A")
elif mark>=70 and mark<=79:
  print("grade:B")
elif mark>=60 and mark<=69:
  print("grade:C")
elif mark>=50 and mark<=59:
  print("grade:D")
else:
  print("fail")
# Out:
# enter your mark67
# grade:C

# %%
#12.electricity bill

# %%
units_consumed=int(input("enter units consumed"))
if units_consumed<=100:
  print("total bill:",units_consumed*2)
elif units_consumed<=200:
  print("total bill:",units_consumed*3)
elif units_consumed<=300:
  print("total bill:",units_consumed*5)
else:
  print("total bill:",units_consumed*7)
# Out:
# enter units consumed437
# total bill: 3059

# %%
#13.atm withdrawal

# %%
balance=int(input("enter your balance"))
withdrawal=int(input("enter your withdrawal amount"))
if balance>=withdrawal:
  print("withdrawal amount is valid")
  print("remaining balance is",balance-withdrawal)
elif withdrawal>balance:
  print("insufficient balance")
else:
  print("try again")
# Out:
# enter your balance800
# enter your withdrawal amount1000
# insufficient balance

# %%
#14.simple login system

# %%
username=input("enter your user name")
password=input("enter your password")
username1="aleena"
password1="jaleel000"
if username==username1 and password==password1:
  print("login successfull")
elif username==username1 and password!=password1:
  print("incorrect password")
elif username!=username1 and password==password1:
  print("incorrect username")
else:
  print("both are incorrect")
# Out:
# enter your user namehgdehfd
# enter your passwordfghqwfd
# both are incorrect

# %%
#15.movie ticket

# %%
age=int(input("enter your age"))
if age<5:
  print("ticket price:free")
elif  age >=5 and age<=12:
  print("ticket price:100")
elif age>=13 and age<=59:
  print("ticket price:200")
else:
  print("ticket price:120")
# Out:
# enter your age34
# ticket price:200

# %%
#16. Traffic Signal

# %%
colour=input("enter your colour")
if colour=="red":
  print("stop")
elif colour=="yellow":
  print("ready")
elif colour=="green":
  print("go")
else:
  print("invalid colour")
# Out:
# enter your colourred
# stop

# %%
#16. Traffic Signal

# %%
height=float(input("enter your height in meters"))
weight=float(input("enter your weight in kg"))
BMI=(weight/(height*height))
if BMI<18.5:
  print("underweight")
elif BMI>=18.5 and BMI<=24.9:
  print("normal weight")
elif BMI>=25 and BMI<=29.9:
  print("overweight")
elif BMI>=30:
  print("obese")
